# %% [markdown]
# <a href="https://colab.research.google.com/github/lmansf/DataFramework/blob/main/Notebook_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Predictions

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.svm import SVR
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor
from sklearn.datasets import make_regression
import joblib

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
Data = pd.read_csv('/content/drive/MyDrive/House Prices/Notebook3.csv')
original = pd.read_csv('/content/drive/MyDrive/House Prices/test.csv')
loaded_model = joblib.load("/content/drive/MyDrive/House Prices/XGBoostRegressor.pkl")

Predictions = loaded_model.predict(Data)
final = pd.DataFrame(original['Id'])
final['SalePrice'] = Predictions

# %%
final.head()
# Out:
#      Id      SalePrice
# 0  1461  142685.406250
# 1  1462  139475.609375
# 2  1463  159249.609375
# 3  1464  166794.906250
# 4  1465  267554.312500

# %%
final.to_csv('/content/drive/MyDrive/House Prices/FinalPredictions.csv', index=False)
